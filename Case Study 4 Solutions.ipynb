# %%
import pandas as pd
import numpy as np

air = pd.read_csv("airquality.csv",header = 0)

#Fetch the observations for 9 day of June
air[(air.Month == 6) & (air.Day == 9)]

#Find Average temperature for the month of June. 
air[(air.Month == 6)]['Temp'].mean()

#To which day of June has the least temperature
air[(air.Temp == air[(air.Month == 6)]['Temp'].min()) & (air.Month == 6)]['Day']

#Find Maximum Ozone value for the month of May
air[air.Month == 5]['Ozone'].max()

#Find the count of the missing values in the ozone column of the data set
sum(pd.isnull(air.Ozone))

#Find out What is the mean of the Ozone column in this dataset
air[['Ozone']].mean()

#Find out which month has the highest temperature
air[air.Temp == air.Temp.max()]['Month']

#Find out the wind value when the Ozone becomes maximum
air[air.Ozone == air.Ozone.max()]['Wind']

#Find out the months for which the airquality observations have been carried out
set(air.Month)

#Find the Ozone and temperature values for the 1st observation of every month.
air[air.Day == 1][['Ozone','Temp','Month']]

#Which day of which month corresponds to the least Ozone Value. 
air[air.Ozone == air.Ozone.max()][['Day','Month']]

#Convert the temperature for all the observations to Centigrade scale
air['Cent_Temp'] = (air.Temp-32)*(5/9)
air.Cent_Temp
# Out:
# 0      19.444444
# 1      22.222222
# 2      23.333333
# 3      16.666667
# 4      13.333333
# 5      18.888889
# 6      18.333333
# 7      15.000000
# 8      16.111111
# 9      20.555556
# 10     23.333333
# 11     20.555556
# 12     18.888889
# 13     20.000000
# 14     14.444444
# 15     17.777778
# 16     18.888889
# 17     13.888889
# 18     20.000000
# 19     16.666667
# 20     15.000000
# 21     22.777778
# 22     16.111111
# 23     16.111111
# 24     13.888889
# 25     14.444444
# 26     13.888889
# 27     19.444444
# 28     27.222222
# 29     26.111111
#          ...
# 123    32.777778
# 124    33.333333
# 125    33.888889
# 126    33.888889
# 127    30.555556
# 128    28.888889
# 129    26.666667
# 130    25.555556
# 131    23.888889
# 132    22.777778
# 133    27.222222
# 134    24.444444
# 135    25.000000
# 136    21.666667
# 137    21.666667
# 138    25.555556
# 139    19.444444
# 140    24.444444
# 141    20.000000
# 142    27.777778
# 143    17.777778
# 144    21.666667
# 145    27.222222
# 146    20.555556
# 147    17.222222
# 148    21.111111
# 149    25.000000
# 150    23.888889
# 151    24.444444
# 152    20.000000
# Name: Cent_Temp, Length: 153, dtype: float64
